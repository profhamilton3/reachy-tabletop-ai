# %%
from reachy_sdk import ReachySDK

reachy = ReachySDK(host="10.22.128.199")
reachy.turn_on("r_arm")

print(reachy.joints.keys())

# %% [markdown]
# #Reachy right arm movement test code
#
# import the SDK and time libraries

# %%
frame = reachy.left_camera.wait_for_new_frame()

import cv2
cv2.imshow("Camera", frame)
cv2.waitKey(0)

# %% [markdown]
# #
