# %%
# # 1. UPDATED MOUSE CLICK FUNCTION WITH SAFETY LIMIT
clicked_points = []
def click_event(event, x, y, flags, params):
    global clicked_points
    if event == cv2.EVENT_LBUTTONDOWN:
        # Stop registering clicks if we already have 4 points
        if len(clicked_points) < 4:
            clicked_points.append([x, y])
            cv2.circle(img_copy, (x, y), 5, (0, 0, 255), -1)
            
            # Print feedback to terminal so you can keep track
            print(f"Point {len(clicked_points)} registered at ({x}, {y})")
            
            # Update the display window
            title = "Click 4 inner corners: Top-Left, Top-Right, Bottom-Left, Bottom-Right"
            cv2.imshow(title, img_copy)
        else:
            print("Warning: Already registered 4 points! Extra click ignored.")

# %%
import numpy as np
import cv2
import glob
import os

# 1. SETUP TERMINATION CRITERIA FOR SUB-PIXEL ACCURACY
# Stops when accuracy hits 0.001 or after 30 loops
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# 2. DEFINE THE CHESSBOARD GEOMETRY
# Number of INSIDE corners on your physical calibration grid
CHECKERBOARD = (2, 2)  # Change this to match your specific board size
SQUARE_SIZE = 0.127    # Size of a square side in meters (e.g., 25mm = 0.025m)

# 3. PREPARE 3D OBJECT POINTS
# These are coordinates like (0,0,0), (1,0,0), (2,0,0) ...
objp = np.zeros((CHECKERBOARD[0] * CHECKERBOARD[1], 3), np.float32)
objp[:, :2] = np.mgrid[0:CHECKERBOARD[0], 0:CHECKERBOARD[1]].T.reshape(-1, 2)
objp *= SQUARE_SIZE

# Arrays to store 3D points and 2D image points from all images
objpoints = []  # 3D points in real-world space
imgpoints_l = []  # 2D points in left camera image plane
imgpoints_r = []  # 2D points in right camera image plane

# 4. LOAD IMAGES
# Make sure your file names or paths match your image folders
base_path = os.path.expanduser('~/dev/reachy-2026-iitg/reachy-tabletop-ai/data/calibration/calib_images')

images_left = sorted(glob.glob(os.path.join(base_path, 'left', '*.png')))
images_right = sorted(glob.glob(os.path.join(base_path, 'right', '*.png')))

# Ensure we have a matching pairs of stereo images
assert len(images_left) == len(images_right), "Number of left and right images must match!"

# 5. FIND CORNERS IN BOTH CAMERAS

for img_l_path, img_r_path in zip(images_left, images_right):
    img_l = cv2.imread(img_l_path)
    img_r = cv2.imread(img_r_path)
    gray_l = cv2.cvtColor(img_l, cv2.COLOR_BGR2GRAY)
    gray_r = cv2.cvtColor(img_r, cv2.COLOR_BGR2GRAY)

    window_title = "Click 4 inner corners: Top-Left, Top-Right, Bottom-Left, Bottom-Right"

    # --- PROCESS LEFT IMAGE ---
    print(f"\n--- Processing Left Image: {os.path.basename(img_l_path)} ---")
    clicked_points = []
    img_copy = img_l.copy()
    cv2.imshow(window_title, img_copy)
    cv2.setMouseCallback(window_title, click_event)
    cv2.waitKey(0) # Press ANY KEY on your keyboard after making your 4 clicks
    
    # Check if exactly 4 points were collected
    if len(clicked_points) != 4:
        print(f"Error: You clicked {len(clicked_points)} times. Must be exactly 4. Skipping this pair.")
        continue
    corners_l = np.array(clicked_points, dtype=np.float32).reshape(-1, 1, 2)

    # --- PROCESS RIGHT IMAGE ---
    print(f"--- Processing Right Image: {os.path.basename(img_r_path)} ---")
    clicked_points = []
    img_copy = img_r.copy()
    cv2.imshow(window_title, img_copy)
    cv2.setMouseCallback(window_title, click_event)
    cv2.waitKey(0) # Press ANY KEY on your keyboard after making your 4 clicks
    
    # Check if exactly 4 points were collected
    if len(clicked_points) != 4:
        print(f"Error: You clicked {len(clicked_points)} times. Must be exactly 4. Skipping this pair.")
        continue
    corners_r = np.array(clicked_points, dtype=np.float32).reshape(-1, 1, 2)

    cv2.destroyAllWindows()

    # Refine the clicked points to sub-pixel accuracy automatically
    corners_l = cv2.cornerSubPix(gray_l, corners_l, (11, 11), (-1, -1), criteria)
    corners_r = cv2.cornerSubPix(gray_r, corners_r, (11, 11), (-1, -1), criteria)

    objpoints.append(objp)
    imgpoints_l.append(corners_l)
    imgpoints_r.append(corners_r)

# Get the resolution of the images (width, height)
img_shape = gray_l.shape[::-1]

# 6. STEP 1: INDIVIDUAL CAMERA CALIBRATION (INTRINSICS)
# Calibrate left camera
ret_l, mtx_l, dist_l, rvecs_l, tvecs_l = cv2.calibrateCamera(
    objpoints, imgpoints_l, img_shape, None, None
)

# Calibrate right camera
ret_r, mtx_r, dist_r, rvecs_r, tvecs_r = cv2.calibrateCamera(
    objpoints, imgpoints_r, img_shape, None, None
)

# 7. STEP 2: STEREO CALIBRATION (EXTRINSICS)
# This calculates the physical distance and rotation between the two cameras
flags = cv2.CALIB_FIX_INTRINSIC  # Keep individual camera shapes locked

retval, mtx_l, dist_l, mtx_r, dist_r, R, T, E, F = cv2.stereoCalibrate(
    objpoints, imgpoints_l, imgpoints_r,
    mtx_l, dist_l, mtx_r, dist_r,
    img_shape, criteria=criteria, flags=flags
)

# 8. STEP 3: RECTIFICATION FOR DEPTH MAPPING
# This creates alignment maps so pixels match up horizontally for stereo depth matching
R1, R2, P1, P2, Q, validRoi1, validRoi2 = cv2.stereoRectify(
    mtx_l, dist_l, mtx_r, dist_r, img_shape, R, T
)

# 9. SAVE THE CALIBRATION PARAMS TO DISK
# You can load this .npz file later into your real-time depth matching code
np.savez('stereo_calibration.npz', 
         mtx_l=mtx_l, dist_l=dist_l, 
         mtx_r=mtx_r, dist_r=dist_r, 
         R=R, T=T, R1=R1, R2=R2, P1=P1, P2=P2, Q=Q)

print("Stereo Calibration Complete! File saved as 'stereo_calibration.npz'")
print(f"Cameras are spaced apart by (Translation Vector T in meters):\n {T}")
# Out:
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_1.png ---
# Point 1 registered at (174, 419)
# Point 2 registered at (384, 383)
# Point 3 registered at (154, 629)
# Point 4 registered at (472, 574)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_1.png ---
# Point 1 registered at (103, 439)
# Point 2 registered at (318, 404)
# Point 3 registered at (73, 628)
# Point 4 registered at (383, 598)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_14.png ---
# Point 1 registered at (84, 362)
# Point 2 registered at (293, 320)
# Point 3 registered at (100, 578)
# Point 4 registered at (394, 501)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_14.png ---
# Point 1 registered at (20, 384)
# Point 2 registered at (222, 340)
# Point 3 registered at (22, 585)
# Point 4 registered at (308, 528)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_16.png ---
# Point 1 registered at (108, 210)
# Point 2 registered at (320, 268)
# Point 3 registered at (17, 412)
# Point 4 registered at (328, 487)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_16.png ---
# Point 1 registered at (42, 234)
# Point 2 registered at (253, 287)
# Point 3 registered at (3, 451)
# Point 4 registered at (232, 506)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_18.png ---
# Point 1 registered at (130, 440)
# Point 2 registered at (339, 417)
# Point 3 registered at (108, 632)
# Point 4 registered at (416, 596)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_18.png ---
# Point 1 registered at (66, 453)
# Point 2 registered at (273, 438)
# Point 3 registered at (38, 629)
# Point 4 registered at (330, 615)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_19.png ---
# Point 1 registered at (90, 341)
# Point 2 registered at (301, 326)
# Point 3 registered at (69, 549)
# Point 4 registered at (372, 520)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_19.png ---
# Point 1 registered at (26, 359)
# Point 2 registered at (233, 347)
# Point 3 registered at (3, 552)
# Point 4 registered at (281, 543)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_2.png ---
# Point 1 registered at (141, 343)
# Point 2 registered at (353, 319)
# Point 3 registered at (123, 551)
# Point 4 registered at (426, 507)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_2.png ---
# Point 1 registered at (70, 362)
# Point 2 registered at (275, 332)
# Point 3 registered at (46, 557)
# Point 4 registered at (342, 532)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_20.png ---
# Point 1 registered at (125, 245)
# Point 2 registered at (340, 218)
# Point 3 registered at (110, 460)
# Point 4 registered at (408, 421)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_20.png ---
# Point 1 registered at (54, 266)
# Point 2 registered at (266, 238)
# Point 3 registered at (33, 473)
# Point 4 registered at (319, 440)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_4.png ---
# Point 1 registered at (129, 391)
# Point 2 registered at (335, 363)
# Point 3 registered at (115, 596)
# Point 4 registered at (416, 555)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_4.png ---
# Point 1 registered at (59, 411)
# Point 2 registered at (263, 383)
# Point 3 registered at (38, 596)
# Point 4 registered at (329, 572)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_5.png ---
# Point 1 registered at (153, 351)
# Point 2 registered at (360, 371)
# Point 3 registered at (90, 538)
# Point 4 registered at (393, 572)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_5.png ---
# Point 1 registered at (83, 368)
# Point 2 registered at (290, 393)
# Point 3 registered at (11, 548)
# Point 4 registered at (305, 591)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_6.png ---
# Point 1 registered at (175, 276)
# Point 2 registered at (388, 270)
# Point 3 registered at (137, 479)
# Point 4 registered at (438, 469)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_6.png ---
# Point 1 registered at (105, 293)
# Point 2 registered at (316, 286)
# Point 3 registered at (58, 497)
# Point 4 registered at (356, 494)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_7.png ---
# Point 1 registered at (135, 381)
# Point 2 registered at (343, 384)
# Point 3 registered at (91, 578)
# Point 4 registered at (397, 579)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_7.png ---
# Point 1 registered at (62, 397)
# Point 2 registered at (274, 402)
# Point 3 registered at (14, 577)
# Point 4 registered at (308, 597)
#
# --- Processing Left Image: Left Camera_screenshot_20.08.2026_9.png ---
# Point 1 registered at (190, 381)
# Point 2 registered at (386, 311)
# Point 3 registered at (208, 576)
# Point 4 registered at (477, 498)
# --- Processing Right Image: Right Camera_screenshot_20.08.2026_9.png ---
# Point 1 registered at (116, 394)
# Point 2 registered at (313, 327)
# Point 3 registered at (123, 592)
# Point 4 registered at (411, 510)
# Stereo Calibration Complete! File saved as 'stereo_calibration.npz'
# Cameras are spaced apart by (Translation Vector T in meters):
#  [[-0.06212742]
#  [ 0.04407251]
#  [ 0.31627393]]

# %%
import numpy as np
from datetime import datetime

# Load your completed calibration file
data = np.load('stereo_calibration.npz')

# Extract left and right intrinsic matrices
mtx_l = data['mtx_l']
mtx_r = data['mtx_r']

# Extract distortion arrays and ensure they are flat lists
dist_l = data['dist_l'].flatten().tolist()
dist_r = data['dist_r'].flatten().tolist()

# Extract structural Extrinsics
R_mat = data['R'].tolist()
T_vec = data['T'].flatten().tolist()

# Baseline calculation (Physical distance between cameras)
# The absolute value of the X-axis coordinate in the translation vector is the baseline
baseline_m = abs(T_vec[0]) 

# Print out your formatted values
print("--- COPY AND PASTE THESE VALUES INTO YOUR JSON ---")
print(f'  "baseline_m": {baseline_m},')
print(f'  "image_width": 1920,')
print(f'  "image_height": 1080,')
print('  "camera_left": {')
print(f'    "fx": {mtx_l[0,0]}, "fy": {mtx_l[1,1]}, "cx": {mtx_l[0,2]}, "cy": {mtx_l[1,2]},')
print(f'    "distortion": {dist_l[:5]}')
print('  },')
print('  "camera_right": {')
print(f'    "fx": {mtx_r[0,0]}, "fy": {mtx_r[1,1]}, "cx": {mtx_r[0,2]}, "cy": {mtx_r[1,2]},')
print(f'    "distortion": {dist_r[:5]}')
print('  },')
print(f'  "R": {R_mat},')
print(f'  "T": {T_vec},')
print(f'  "calibrated_at": "{datetime.now().strftime("%Y-%m-%d %H:%M:%S")}",')
print('  "rms_error_px": null')
# Out:
# --- COPY AND PASTE THESE VALUES INTO YOUR JSON ---
#   "baseline_m": 0.0621274178595431,
#   "image_width": 1920,
#   "image_height": 1080,
#   "camera_left": {
#     "fx": 443.7800085677336, "fy": 427.2254922168495, "cx": 260.50418470367805, "cy": 304.7926156049493,
#     "distortion": [-0.44944136977854077, 0.16687719874964987, 0.029186849970304133, 0.008829587332202125, -0.009264602250212143]
#   },
#   "camera_right": {
#     "fx": 983.1419974525278, "fy": 1010.9294605219159, "cx": 241.20997686374463, "cy": 177.5246961639785,
#     "distortion": [4.075793214944004, -7.07224111376786, -0.3812392546217548, 0.33135666034486094, 7.3783776193704576]
#   },
#   "R": [[0.9940997467695805, 0.05867421205566133, 0.0912306434938579], [-0.07510408115402986, 0.979172253101894, 0.18862946681091308], [-0.07826282940620666, -0.19436829884270673, 0.9778015616362695]],
#   "T": [-0.0621274178595431, 0.044072508306066065, 0.31627392514796043],
#   "calibrated_at": "2026-08-21 17:12:21",
#   "rms_error_px": null
